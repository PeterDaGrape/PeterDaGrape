# %%
# Example file showing a circle moving on screen
import pygame
import random

import numpy as np

import random
import math

# %%
epsilon = 0.6
epsilonDecay = 0.999
discount = 0.95
learning_rate = 0.1


resolution = (640, 360) 

accelerationDecay = 0.9995
global simpleDifficulty


# pygame setup
pygame.init()
screen = pygame.display.set_mode(resolution)
clock = pygame.time.Clock()


global paddle1Y

paddleHeight = 90


ballRad = 10
ball = pygame.Vector2(screen.get_width() / 2, screen.get_height() / 2)


global ballPosY

global ballVec


q_table_shape = [20, 20, 20, 20]

game = 0

# %%
def simpleAI(paddleY, targetY):
    if targetY > paddleY:
        paddleY += simpleDifficulty

    else:
        paddleY -= simpleDifficulty

    return paddleY 

def collision(ball, paddle_rect):
    ball_rect = pygame.Rect(ball.x - ballRad, ball.y - ballRad, ballRad*2, ballRad*2)
    if ball_rect.colliderect(paddle_rect):
        # Collision detected
        return True
    else:
        # No collision detected
        return False
    

def discretize(ball_x, ball_y, paddle_y, vel_x, vel_y):
    discrete_x = int(ball_x / resolution[0]) * q_table_shape[0]
    discrete_y = int((ball_y - paddle_y) / resolution[1] * q_table_shape[1])



    dis_vel_x = int((vel_x + 10) / 20 * q_table_shape[2])
    dis_vel_y = int((vel_y + 10) / 20 * q_table_shape[3])

    

    return tuple((discrete_x, discrete_y, dis_vel_x, dis_vel_y))

# %%
# Example file showing a circle moving on screen
import pygame
import random

import numpy as np

import random
import math



# Define the epsilon-greedy policy

epsilon = 0.6
epsilonDecay = 0.999
discount = 0.95
learning_rate = 0.1





def simpleAI(paddleY, targetY):
    if targetY > paddleY:
        paddleY += simpleDifficulty

    else:
        paddleY -= simpleDifficulty

    return paddleY 

def collision(ball, paddle_rect):
    ball_rect = pygame.Rect(ball.x - ballRad, ball.y - ballRad, ballRad*2, ballRad*2)
    if ball_rect.colliderect(paddle_rect):
        # Collision detected
        return True
    else:
        # No collision detected
        return False

resolution = (640, 360) 

accelerationDecay = 0.9995
global simpleDifficulty


# pygame setup
pygame.init()
screen = pygame.display.set_mode(resolution)
clock = pygame.time.Clock()


global paddle1Y

paddleHeight = 90


ballRad = 10
ball = pygame.Vector2(screen.get_width() / 2, screen.get_height() / 2)


global ballPosY

global ballVec


q_table_shape = [20, 20, 20, 20]

game = 0
def discretize(ball_x, ball_y, paddle_y, vel_x, vel_y):
    discrete_x = int(ball_x / resolution[0]) * q_table_shape[0]
    discrete_y = int((ball_y - paddle_y) / resolution[1] * q_table_shape[1])



    dis_vel_x = int((vel_x + 10) / 20 * q_table_shape[2])
    dis_vel_y = int((vel_y + 10) / 20 * q_table_shape[3])

    

    return tuple((discrete_x, discrete_y, dis_vel_x, dis_vel_y))






num_actions = 3



q_table = np.random.uniform(low = -2, high = 0, size = (q_table_shape + [num_actions]))



while True:
    game += 1

    acceleration = 0.001
    
    simpleDifficulty = 2.5
    paddle1Y = resolution[1] / 2
    paddle2Y = resolution[1] / 2

    gameOver = False

    initialVel = 4

    randomStart = random.randint(40, 80)
    randomDir = random.randint(0,1)
    ballPosX, ballPosY = resolution[0] / 2, resolution[1] / 2
    if randomDir == 0:
        dirMult = 1
    else:
        dirMult = -1
    ballVelX = (randomStart / 100) * initialVel
    ballVelY = (((initialVel ** 2) - (((randomStart / 100) * initialVel)  ** 2))**0.5) * dirMult

    state = discretize(ballPosX, ballPosY, paddle2Y, ballVelX, ballVelY)
    total_reward = 0
    print('Starting Game, ', game)
    while gameOver != True:
        reward = 0


        # poll for events

        

        # pygame.QUIT event means the user clicked X to close your window
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                gameOver = True

        # fill the screen with a color to wipe away anything from last frame

        paddle1 = pygame.Rect(0.075*resolution[0], paddle1Y - paddleHeight/2, 10, paddleHeight)
        paddle2 = pygame.Rect(0.925*resolution[0], paddle2Y - paddleHeight/2, 10, paddleHeight)

        screen.fill("white")

        pygame.draw.circle(screen, "red", ball, ballRad)
        pygame.draw.rect(screen, 'black', paddle1)
        pygame.draw.rect(screen, 'black', paddle2)


        
        if collision(ball, paddle1):
            ballVelX = -ballVelX
            reward -= 1
        elif collision(ball, paddle2):
            ballVelX = -ballVelX
            reward += 10


        if ballPosY < ballRad or ballPosY > resolution[1] - ballRad:
            ballVelY = -ballVelY
        if ballPosX < ballRad:
            winner = 1
            gameOver = True
            reward += 6
            print('CoolAI wins')
        elif ballPosX > resolution[0] - ballRad:
            gameOver = True
            winner = 2
            reward -= 8
            print('BoringAI wins')


        prevHeight = paddle2Y

        



        ballPosX += ballVelX
        ballPosY += ballVelY



        paddle1Y = simpleAI(paddle1Y, ballPosY)
        

        if random.uniform(0, 1) < epsilon:
            action = random.randint(0, num_actions-1)
        else:
            try:
                action = np.argmax(q_table[state])
            except:
                action = 0        

        

        if action == 1:
            paddle2Y -= 5
        elif action == 2:
            if paddle2Y < resolution[1]:
                if paddle2Y > 0:
                    paddle2Y += 5
        else:
            paddle2Y += 0
            reward -= 0.1
        

            
        
        new_state = discretize(ballPosX, ballPosY, paddle2Y, ballVelX, ballVelY)
        
        if not gameOver:
            try:
                max_future_q = np.max(q_table[new_state])

                current_q = q_table[state + (action, )]

                new_q = (1 - learning_rate) * current_q + learning_rate * (reward + discount * max_future_q)

                q_table[state + (action, )] = new_q
            except:
                pass
        

        state = new_state

        ball.xy = ballPosX, ballPosY

        
            

        




        pygame.display.flip()

        #clock.tick(60)

        ballVelX = ballVelX + acceleration * ballVelX
        ballVelY = ballVelY + acceleration * ballVelY
        acceleration *= accelerationDecay
        total_reward += reward


    if winner == 1:
        simpleDifficulty += 0.2
    else:
        if simpleDifficulty > 2:
            simpleDifficulty -= 0.1

    print('The AI scored ', total_reward, 'epsilon is', epsilon)
    print('The simpleAI difficulty is now:', simpleDifficulty)


    epsilon *= epsilonDecay




    

        

pygame.quit()
# Out:
# Starting Game,  1
# BoringAI wins
# The AI scored  -12.7 epsilon is 0.6
# The simpleAI difficulty is now: 2.4
# Starting Game,  2
# BoringAI wins
# The AI scored  -12.7 epsilon is 0.5993999999999999
# The simpleAI difficulty is now: 2.4
# Starting Game,  3
# BoringAI wins
# The AI scored  -12.4 epsilon is 0.5988005999999999
# The simpleAI difficulty is now: 2.4
# Starting Game,  4
# BoringAI wins
# The AI scored  -10.599999999999989 epsilon is 0.5982017994
# The simpleAI difficulty is now: 2.4
# Starting Game,  5
# BoringAI wins
# The AI scored  -20.099999999999973 epsilon is 0.5976035976006
# The simpleAI difficulty is now: 2.4
# Starting Game,  6
# BoringAI wins
# The AI scored  -10.599999999999984 epsilon is 0.5970059940029994
# The simpleAI difficulty is now: 2.4
# Starting Game,  7
# BoringAI wins
# The AI scored  -13.099999999999998 epsilon is 0.5964089880089963
# The simpleAI difficulty is now: 2.4
# Starting Game,  8
# CoolAI wins
# The AI scored  9.400000000000011 epsilon is 0.5958125790209874
# The simpleAI difficulty is now: 2.7
# Starting Game,  9
# BoringAI wins
# The AI scored  -11.399999999999999 epsilon is 0.5952167664419664
# The simpleAI difficulty is now: 2.4
# Starting Game,  10
# BoringAI wins
# The AI scored  -11.3 epsilon is 0.5946215496755245
# The simpleAI difficulty is now: 2.4
# Starting Game,  11
# BoringAI wins
# The AI scored  -11.8 epsilon is 0.594026928125849
# The simpleAI difficulty is now: 2.4
# Starting Game,  12
# CoolAI wins
# The AI scored  9.20000000000001 epsilon is 0.5934329011977232
# The simpleAI difficulty is now: 2.7
# Starting Game,  13
# CoolAI wins
# The AI scored  -37.20000000000011 epsilon is 0.5928394682965255
# The simpleAI difficulty is now: 2.7
# Starting Game,  14
# BoringAI wins
# The AI scored  -12.899999999999999 epsilon is 0.5922466288282289
# The simpleAI difficulty is now: 2.4
# Starting Game,  15
# CoolAI wins
# The AI scored  9.400000000000011 epsilon is 0.5916543821994007
# The simpleAI difficulty is now: 2.7
# Starting Game,  16
# BoringAI wins
# The AI scored  -12.099999999999994 epsilon is 0.5910627278172013
# The simpleAI difficulty is now: 2.4
# Starting Game,  17
# BoringAI wins
# The AI scored  -10.9 epsilon is 0.5904716650893841
# The simpleAI difficulty is now: 2.4
# Starting Game,  18
# CoolAI wins
# The AI scored  8.600000000000005 epsilon is 0.5898811934242947
# The simpleAI difficulty is now: 2.7
# Starting Game,  19
# BoringAI wins
# The AI scored  -8.29999999999999 epsilon is 0.5892913122308704
# The simpleAI difficulty is now: 2.4
# Starting Game,  20
# BoringAI wins
# The AI scored  -9.499999999999988 epsilon is 0.5887020209186395
# The simpleAI difficulty is now: 2.4
# Starting Game,  21
# BoringAI wins
# The AI scored  -8.499999999999988 epsilon is 0.5881133188977209
# The simpleAI difficulty is now: 2.4
# Starting Game,  22
# BoringAI wins
# The AI scored  -10.900000000000002 epsilon is 0.5875252055788232
# The simpleAI difficulty is now: 2.4
# Starting Game,  23
# CoolAI wins
# The AI scored  5.90000000000001 epsilon is 0.5869376803732443
# The simpleAI difficulty is now: 2.7
# Starting Game,  24
# CoolAI wins
# The AI scored  10.40000000000002 epsilon is 0.5863507426928711
# The simpleAI difficulty is now: 2.7
# Starting Game,  25
# BoringAI wins
# The AI scored  424.7999999999997 epsilon is 0.5857643919501783
# The simpleAI difficulty is now: 2.4
# Starting Game,  26
# BoringAI wins
# The AI scored  -10.799999999999988 epsilon is 0.5851786275582281
# The simpleAI difficulty is now: 2.4
# Starting Game,  27
# BoringAI wins
# The AI scored  -11.900000000000002 epsilon is 0.5845934489306699
# The simpleAI difficulty is now: 2.4
# Starting Game,  28
# CoolAI wins
# The AI scored  5.900000000000007 epsilon is 0.5840088554817392
# The simpleAI difficulty is now: 2.7
# Starting Game,  29
# BoringAI wins
# The AI scored  -11.700000000000003 epsilon is 0.5834248466262575
# The simpleAI difficulty is now: 2.4
# Starting Game,  30
# BoringAI wins
# The AI scored  -11.400000000000002 epsilon is 0.5828414217796313
# The simpleAI difficulty is now: 2.4
# Starting Game,  31
# BoringAI wins
# The AI scored  -7.499999999999989 epsilon is 0.5822585803578516
# The simpleAI difficulty is now: 2.4
# Starting Game,  32
# CoolAI wins
# The AI scored  9.00000000000001 epsilon is 0.5816763217774937
# The simpleAI difficulty is now: 2.7
# Starting Game,  33
# BoringAI wins
# The AI scored  -10.900000000000002 epsilon is 0.5810946454557162
# The simpleAI difficulty is now: 2.4
# Starting Game,  34
# BoringAI wins
# The AI scored  -11.400000000000002 epsilon is 0.5805135508102605
# The simpleAI difficulty is now: 2.4
# Starting Game,  35
# BoringAI wins
# The AI scored  -12.899999999999999 epsilon is 0.5799330372594502
# The simpleAI difficulty is now: 2.4
# Starting Game,  36
# CoolAI wins
# The AI scored  269.49999999999704 epsilon is 0.5793531042221908
# The simpleAI difficulty is now: 2.7
# Starting Game,  37
# BoringAI wins
# The AI scored  -10.900000000000002 epsilon is 0.5787737511179686
# The simpleAI difficulty is now: 2.4
# Starting Game,  38
# BoringAI wins
# The AI scored  -13.099999999999998 epsilon is 0.5781949773668507
# The simpleAI difficulty is now: 2.4
# Starting Game,  39
# BoringAI wins
# The AI scored  -11.0 epsilon is 0.5776167823894838
# The simpleAI difficulty is now: 2.4
# Starting Game,  40
# BoringAI wins
# The AI scored  345.7999999999997 epsilon is 0.5770391656070943
# The simpleAI difficulty is now: 2.4
# Starting Game,  41
# BoringAI wins
# The AI scored  -10.5 epsilon is 0.5764621264414872
# The simpleAI difficulty is now: 2.4
# Starting Game,  42
# BoringAI wins
# The AI scored  -10.3 epsilon is 0.5758856643150457
# The simpleAI difficulty is now: 2.4
# Starting Game,  43
# BoringAI wins
# The AI scored  -12.39999999999998 epsilon is 0.5753097786507306
# The simpleAI difficulty is now: 2.4
# Starting Game,  44
# BoringAI wins
# The AI scored  -12.4 epsilon is 0.5747344688720799
# The simpleAI difficulty is now: 2.4
# Starting Game,  45
# BoringAI wins
# The AI scored  175.3000000000015 epsilon is 0.5741597344032078
# The simpleAI difficulty is now: 2.4
# Starting Game,  46
# CoolAI wins
# The AI scored  6.90000000000001 epsilon is 0.5735855746688046
# The simpleAI difficulty is now: 2.7
# Starting Game,  47
# BoringAI wins
# The AI scored  -11.200000000000001 epsilon is 0.5730119890941358
# The simpleAI difficulty is now: 2.4
# Starting Game,  48
# CoolAI wins
# The AI scored  2.700000000000001 epsilon is 0.5724389771050417
# The simpleAI difficulty is now: 2.7
# Starting Game,  49
# BoringAI wins
# The AI scored  -10.4 epsilon is 0.5718665381279366
# The simpleAI difficulty is now: 2.4
# Starting Game,  50
# BoringAI wins
# The AI scored  -10.8 epsilon is 0.5712946715898087
# The simpleAI difficulty is now: 2.4
# Starting Game,  51
# BoringAI wins
# The AI scored  -10.700000000000001 epsilon is 0.570723376918219
# The simpleAI difficulty is now: 2.4
# Starting Game,  52
# BoringAI wins
# The AI scored  -11.299999999999988 epsilon is 0.5701526535413007
# The simpleAI difficulty is now: 2.4
# Starting Game,  53
# BoringAI wins
# The AI scored  -10.5 epsilon is 0.5695825008877594
# The simpleAI difficulty is now: 2.4
# Starting Game,  54
# CoolAI wins
# The AI scored  8.900000000000013 epsilon is 0.5690129183868716
# The simpleAI difficulty is now: 2.7
# Starting Game,  55
# BoringAI wins
# The AI scored  -10.5 epsilon is 0.5684439054684848
# The simpleAI difficulty is now: 2.4
# Starting Game,  56
# BoringAI wins
# The AI scored  -10.3 epsilon is 0.5678754615630163
# The simpleAI difficulty is now: 2.4
# Starting Game,  57
# BoringAI wins
# The AI scored  -10.700000000000001 epsilon is 0.5673075861014533
# The simpleAI difficulty is now: 2.4
# Starting Game,  58
# BoringAI wins
# The AI scored  -11.000000000000002 epsilon is 0.5667402785153518
# The simpleAI difficulty is now: 2.4
# Starting Game,  59
# BoringAI wins
# The AI scored  -11.899999999999991 epsilon is 0.5661735382368365
# The simpleAI difficulty is now: 2.4
# Starting Game,  60
# BoringAI wins
# The AI scored  -11.400000000000002 epsilon is 0.5656073646985996
# The simpleAI difficulty is now: 2.4
# Starting Game,  61
# CoolAI wins
# The AI scored  8.000000000000007 epsilon is 0.565041757333901
# The simpleAI difficulty is now: 2.7
# Starting Game,  62
# BoringAI wins
# The AI scored  -11.3 epsilon is 0.5644767155765672
# The simpleAI difficulty is now: 2.4
# Starting Game,  63
# BoringAI wins
# The AI scored  -12.899999999999999 epsilon is 0.5639122388609906
# The simpleAI difficulty is now: 2.4
# Starting Game,  64
# BoringAI wins
# The AI scored  -11.900000000000002 epsilon is 0.5633483266221296
# The simpleAI difficulty is now: 2.4
# Starting Game,  65
# BoringAI wins
# The AI scored  -10.700000000000001 epsilon is 0.5627849782955076
# The simpleAI difficulty is now: 2.4
# Starting Game,  66
# BoringAI wins
# The AI scored  -13.199999999999998 epsilon is 0.562222193317212
# The simpleAI difficulty is now: 2.4
# Starting Game,  67
# BoringAI wins
# The AI scored  -10.100000000000001 epsilon is 0.5616599711238948
# The simpleAI difficulty is now: 2.4
# Starting Game,  68
# BoringAI wins
# The AI scored  -10.49999999999999 epsilon is 0.5610983111527709
# The simpleAI difficulty is now: 2.4
# Starting Game,  69
# BoringAI wins
# The AI scored  -11.199999999999992 epsilon is 0.5605372128416181
# The simpleAI difficulty is now: 2.4
# Starting Game,  70
# BoringAI wins
# The AI scored  -12.3 epsilon is 0.5599766756287764
# The simpleAI difficulty is now: 2.4
# Starting Game,  71
# BoringAI wins
# The AI scored  -12.6 epsilon is 0.5594166989531476
# The simpleAI difficulty is now: 2.4
# Starting Game,  72
# BoringAI wins
# The AI scored  326.7999999999997 epsilon is 0.5588572822541945
# The simpleAI difficulty is now: 2.4
# Starting Game,  73
# CoolAI wins
# The AI scored  7.800000000000008 epsilon is 0.5582984249719403
# The simpleAI difficulty is now: 2.7
# Starting Game,  74
# CoolAI wins
# The AI scored  6.800000000000012 epsilon is 0.5577401265469684
# The simpleAI difficulty is now: 2.7
# Starting Game,  75
# BoringAI wins
# The AI scored  -9.8 epsilon is 0.5571823864204214
# The simpleAI difficulty is now: 2.4
# Starting Game,  76
# BoringAI wins
# The AI scored  366.7999999999981 epsilon is 0.556625204034001
# The simpleAI difficulty is now: 2.4
# Starting Game,  77
# BoringAI wins
# The AI scored  -10.299999999999992 epsilon is 0.556068578829967
# The simpleAI difficulty is now: 2.4
# Starting Game,  78
# BoringAI wins
# The AI scored  -11.000000000000002 epsilon is 0.555512510251137
# The simpleAI difficulty is now: 2.4
# Starting Game,  79
# BoringAI wins
# The AI scored  -8.599999999999989 epsilon is 0.5549569977408859
# The simpleAI difficulty is now: 2.4
# Starting Game,  80
# BoringAI wins
# The AI scored  -10.19999999999999 epsilon is 0.554402040743145
# The simpleAI difficulty is now: 2.4
# Starting Game,  81
# BoringAI wins
# The AI scored  -13.699999999999989 epsilon is 0.5538476387024018
# The simpleAI difficulty is now: 2.4
# Starting Game,  82
# BoringAI wins
# The AI scored  -9.700000000000001 epsilon is 0.5532937910636995
# The simpleAI difficulty is now: 2.4
# Starting Game,  83
# BoringAI wins
# The AI scored  -9.6 epsilon is 0.5527404972726357
# The simpleAI difficulty is now: 2.4
# Starting Game,  84
# BoringAI wins
# The AI scored  -12.4 epsilon is 0.5521877567753631
# The simpleAI difficulty is now: 2.4
# Starting Game,  85
# BoringAI wins
# The AI scored  -12.999999999999998 epsilon is 0.5516355690185878
# The simpleAI difficulty is now: 2.4
# Starting Game,  86
# BoringAI wins
# The AI scored  -12.100000000000001 epsilon is 0.5510839334495692
# The simpleAI difficulty is now: 2.4
# Starting Game,  87
# BoringAI wins
# The AI scored  -10.200000000000001 epsilon is 0.5505328495161196
# The simpleAI difficulty is now: 2.4
# Starting Game,  88
# CoolAI wins
# The AI scored  8.500000000000012 epsilon is 0.5499823166666035
# The simpleAI difficulty is now: 2.7
# Starting Game,  89
# BoringAI wins
# The AI scored  -11.100000000000001 epsilon is 0.5494323343499369
# The simpleAI difficulty is now: 2.4
# Starting Game,  90
# BoringAI wins
# The AI scored  -10.8 epsilon is 0.548882902015587
# The simpleAI difficulty is now: 2.4
# Starting Game,  91
# BoringAI wins
# The AI scored  -9.9 epsilon is 0.5483340191135714
# The simpleAI difficulty is now: 2.4
# Starting Game,  92
# BoringAI wins
# The AI scored  -9.599999999999985 epsilon is 0.5477856850944578
# The simpleAI difficulty is now: 2.4
# Starting Game,  93
# CoolAI wins
# The AI scored  10.800000000000026 epsilon is 0.5472378994093633
# The simpleAI difficulty is now: 2.7
# Starting Game,  94
# BoringAI wins
# The AI scored  -9.69999999999999 epsilon is 0.5466906615099539
# The simpleAI difficulty is now: 2.4
# Starting Game,  95
# BoringAI wins
# The AI scored  -11.100000000000001 epsilon is 0.546143970848444
# The simpleAI difficulty is now: 2.4
# Starting Game,  96
# BoringAI wins
# The AI scored  -12.4 epsilon is 0.5455978268775956
# The simpleAI difficulty is now: 2.4
# Starting Game,  97
# BoringAI wins
# The AI scored  -11.500000000000002 epsilon is 0.545052229050718
# The simpleAI difficulty is now: 2.4
# Starting Game,  98
# CoolAI wins
# The AI scored  10.200000000000017 epsilon is 0.5445071768216673
# The simpleAI difficulty is now: 2.7
# Starting Game,  99
# CoolAI wins
# The AI scored  423.5999999999986 epsilon is 0.5439626696448456
# The simpleAI difficulty is now: 2.7
# Starting Game,  100
# BoringAI wins
# The AI scored  -10.700000000000001 epsilon is 0.5434187069752008
# The simpleAI difficulty is now: 2.4
# Starting Game,  101
# CoolAI wins
# The AI scored  3.700000000000003 epsilon is 0.5428752882682256
# The simpleAI difficulty is now: 2.7
# Starting Game,  102
# CoolAI wins
# The AI scored  -26.500000000000156 epsilon is 0.5423324129799574
# The simpleAI difficulty is now: 2.7
# Starting Game,  103
# CoolAI wins
# The AI scored  619.1999999999931 epsilon is 0.5417900805669774
# The simpleAI difficulty is now: 2.7
# Starting Game,  104
# BoringAI wins
# The AI scored  -10.3 epsilon is 0.5412482904864104
# The simpleAI difficulty is now: 2.4
# Starting Game,  105
# BoringAI wins
# The AI scored  -11.100000000000001 epsilon is 0.540707042195924
# The simpleAI difficulty is now: 2.4
# Starting Game,  106
# BoringAI wins
# The AI scored  -14.699999999999992 epsilon is 0.5401663351537281
# The simpleAI difficulty is now: 2.4
# Starting Game,  107
# BoringAI wins
# The AI scored  -11.3 epsilon is 0.5396261688185744
# The simpleAI difficulty is now: 2.4
# Starting Game,  108
# BoringAI wins
# The AI scored  -12.999999999999998 epsilon is 0.5390865426497559
# The simpleAI difficulty is now: 2.4
# Starting Game,  109
# CoolAI wins
# The AI scored  5.600000000000014 epsilon is 0.5385474561071061
# The simpleAI difficulty is now: 2.7
# Starting Game,  110
# BoringAI wins
# The AI scored  -10.200000000000001 epsilon is 0.5380089086509989
# The simpleAI difficulty is now: 2.4
# Starting Game,  111
# BoringAI wins
# The AI scored  -11.3 epsilon is 0.537470899742348
# The simpleAI difficulty is now: 2.4
# Starting Game,  112
# BoringAI wins
# The AI scored  -11.600000000000001 epsilon is 0.5369334288426056
# The simpleAI difficulty is now: 2.4
# Starting Game,  113
# BoringAI wins
# The AI scored  -11.3 epsilon is 0.536396495413763
# The simpleAI difficulty is now: 2.4
# Starting Game,  114
# CoolAI wins
# The AI scored  9.200000000000012 epsilon is 0.5358600989183492
# The simpleAI difficulty is now: 2.7
# Starting Game,  115
# BoringAI wins
# The AI scored  -11.100000000000001 epsilon is 0.5353242388194308
# The simpleAI difficulty is now: 2.4
# Starting Game,  116
# BoringAI wins
# The AI scored  -11.200000000000001 epsilon is 0.5347889145806114
# The simpleAI difficulty is now: 2.4
# Starting Game,  117
# BoringAI wins
# The AI scored  -11.900000000000002 epsilon is 0.5342541256660308
# The simpleAI difficulty is now: 2.4
# Starting Game,  118
# BoringAI wins
# The AI scored  9.499999999999993 epsilon is 0.5337198715403648
# The simpleAI difficulty is now: 2.4
# Starting Game,  119
# CoolAI wins
# The AI scored  8.100000000000012 epsilon is 0.5331861516688244
# The simpleAI difficulty is now: 2.7
# Starting Game,  120
# BoringAI wins
# The AI scored  -10.700000000000001 epsilon is 0.5326529655171556
# The simpleAI difficulty is now: 2.4
# Starting Game,  121
# CoolAI wins
# The AI scored  -33.599999999999994 epsilon is 0.5321203125516384
# The simpleAI difficulty is now: 2.7
# Starting Game,  122
# BoringAI wins
# The AI scored  -10.700000000000001 epsilon is 0.5315881922390867
# The simpleAI difficulty is now: 2.4
# Starting Game,  123
# BoringAI wins
# The AI scored  -11.100000000000001 epsilon is 0.5310566040468476
# The simpleAI difficulty is now: 2.4
# Starting Game,  124
# CoolAI wins
# The AI scored  369.2999999999994 epsilon is 0.5305255474428008
# The simpleAI difficulty is now: 2.7
# Starting Game,  125
# BoringAI wins
# The AI scored  -10.700000000000001 epsilon is 0.529995021895358
# The simpleAI difficulty is now: 2.4
# Starting Game,  126
# BoringAI wins
# The AI scored  -13.599999999999996 epsilon is 0.5294650268734626
# The simpleAI difficulty is now: 2.4
# Starting Game,  127
# BoringAI wins
# The AI scored  -10.8 epsilon is 0.5289355618465892
# The simpleAI difficulty is now: 2.4
# Starting Game,  128
# BoringAI wins
# The AI scored  -11.100000000000001 epsilon is 0.5284066262847426
# The simpleAI difficulty is now: 2.4
# Starting Game,  129
# CoolAI wins
# The AI scored  -35.7000000000001 epsilon is 0.5278782196584578
# The simpleAI difficulty is now: 2.7
# Starting Game,  130
# BoringAI wins
# The AI scored  -12.000000000000002 epsilon is 0.5273503414387993
# The simpleAI difficulty is now: 2.4
# Starting Game,  131
# BoringAI wins
# The AI scored  -47.900000000000134 epsilon is 0.5268229910973605
# The simpleAI difficulty is now: 2.4
# Starting Game,  132
# CoolAI wins
# The AI scored  211.50000000000037 epsilon is 0.5262961681062631
# The simpleAI difficulty is now: 2.7
# Starting Game,  133
# BoringAI wins
# The AI scored  -10.0 epsilon is 0.5257698719381568
# The simpleAI difficulty is now: 2.4
# Starting Game,  134
# BoringAI wins
# The AI scored  -7.9999999999999885 epsilon is 0.5252441020662186
# The simpleAI difficulty is now: 2.4
# Starting Game,  135
# CoolAI wins
# The AI scored  9.700000000000014 epsilon is 0.5247188579641524
# The simpleAI difficulty is now: 2.7
# Starting Game,  136
# BoringAI wins
# The AI scored  -10.8 epsilon is 0.5241941391061883
# The simpleAI difficulty is now: 2.4
# Starting Game,  137
# BoringAI wins
# The AI scored  -11.500000000000002 epsilon is 0.5236699449670821
# The simpleAI difficulty is now: 2.4
# Starting Game,  138
# BoringAI wins
# The AI scored  -9.9 epsilon is 0.523146275022115
# The simpleAI difficulty is now: 2.4
# Starting Game,  139
# BoringAI wins
# The AI scored  -10.600000000000001 epsilon is 0.5226231287470928
# The simpleAI difficulty is now: 2.4
# Starting Game,  140
# BoringAI wins
# The AI scored  -11.200000000000001 epsilon is 0.5221005056183458
# The simpleAI difficulty is now: 2.4
# Starting Game,  141
# BoringAI wins
# The AI scored  -9.199999999999992 epsilon is 0.5215784051127275
# The simpleAI difficulty is now: 2.4
# Starting Game,  142
# CoolAI wins
# The AI scored  -13.799999999999983 epsilon is 0.5210568267076148
# The simpleAI difficulty is now: 2.7
# Starting Game,  143
# BoringAI wins
# The AI scored  -9.899999999999988 epsilon is 0.5205357698809071
# The simpleAI difficulty is now: 2.4
# Starting Game,  144
# BoringAI wins
# The AI scored  -11.200000000000001 epsilon is 0.5200152341110262
# The simpleAI difficulty is now: 2.4
# Starting Game,  145
# BoringAI wins
# The AI scored  -11.600000000000001 epsilon is 0.5194952188769152
# The simpleAI difficulty is now: 2.4
# Starting Game,  146
# BoringAI wins
# The AI scored  -10.600000000000001 epsilon is 0.5189757236580382
# The simpleAI difficulty is now: 2.4
# Starting Game,  147
# BoringAI wins
# The AI scored  10.0 epsilon is 0.5184567479343802
# The simpleAI difficulty is now: 2.4
# Starting Game,  148
# BoringAI wins
# The AI scored  -10.100000000000001 epsilon is 0.5179382911864459
# The simpleAI difficulty is now: 2.4
# Starting Game,  149
# CoolAI wins
# The AI scored  8.200000000000012 epsilon is 0.5174203528952594
# The simpleAI difficulty is now: 2.7
# Starting Game,  150
# BoringAI wins
# The AI scored  -10.5 epsilon is 0.5169029325423642
# The simpleAI difficulty is now: 2.4
# Starting Game,  151
# CoolAI wins
# The AI scored  14.100000000000023 epsilon is 0.5163860296098218
# The simpleAI difficulty is now: 2.7
# Starting Game,  152
# BoringAI wins
# The AI scored  -10.09999999999999 epsilon is 0.515869643580212
# The simpleAI difficulty is now: 2.4
# Starting Game,  153
# BoringAI wins
# The AI scored  -11.600000000000001 epsilon is 0.5153537739366318
# The simpleAI difficulty is now: 2.4
# Starting Game,  154
# BoringAI wins
# The AI scored  -12.4 epsilon is 0.5148384201626952
# The simpleAI difficulty is now: 2.4
# Starting Game,  155
# BoringAI wins
# The AI scored  -11.400000000000002 epsilon is 0.5143235817425326
# The simpleAI difficulty is now: 2.4
# Starting Game,  156
# BoringAI wins
# The AI scored  -11.000000000000002 epsilon is 0.51380925816079
# The simpleAI difficulty is now: 2.4
# Starting Game,  157
# BoringAI wins
# The AI scored  -11.200000000000001 epsilon is 0.5132954489026292
# The simpleAI difficulty is now: 2.4
# Starting Game,  158
# BoringAI wins
# The AI scored  -8.79999999999999 epsilon is 0.5127821534537266
# The simpleAI difficulty is now: 2.4
# Starting Game,  159
# CoolAI wins
# The AI scored  11.700000000000008 epsilon is 0.5122693713002728
# The simpleAI difficulty is now: 2.7
# Starting Game,  160
# CoolAI wins
# The AI scored  6.200000000000011 epsilon is 0.5117571019289726
# The simpleAI difficulty is now: 2.7
# Starting Game,  161
# BoringAI wins
# The AI scored  -13.299999999999997 epsilon is 0.5112453448270436
# The simpleAI difficulty is now: 2.4
# Starting Game,  162
# BoringAI wins
# The AI scored  -11.400000000000002 epsilon is 0.5107340994822166
# The simpleAI difficulty is now: 2.4
# Starting Game,  163
# BoringAI wins
# The AI scored  -9.9 epsilon is 0.5102233653827344
# The simpleAI difficulty is now: 2.4
# Starting Game,  164
# BoringAI wins
# The AI scored  -12.6 epsilon is 0.5097131420173516
# The simpleAI difficulty is now: 2.4
# Starting Game,  165
# CoolAI wins
# The AI scored  3.3000000000000016 epsilon is 0.5092034288753343
# The simpleAI difficulty is now: 2.7
# Starting Game,  166
# BoringAI wins
# The AI scored  -10.399999999999991 epsilon is 0.508694225446459
# The simpleAI difficulty is now: 2.4
# Starting Game,  167
# BoringAI wins
# The AI scored  -12.200000000000001 epsilon is 0.5081855312210126
# The simpleAI difficulty is now: 2.4
# Starting Game,  168
# CoolAI wins
# The AI scored  10.700000000000012 epsilon is 0.5076773456897916
# The simpleAI difficulty is now: 2.7
# Starting Game,  169
# CoolAI wins
# The AI scored  5.500000000000006 epsilon is 0.5071696683441018
# The simpleAI difficulty is now: 2.7
# Starting Game,  170
# BoringAI wins
# The AI scored  289.9999999999983 epsilon is 0.5066624986757577
# The simpleAI difficulty is now: 2.4
# Starting Game,  171
# BoringAI wins
# The AI scored  -11.600000000000001 epsilon is 0.506155836177082
# The simpleAI difficulty is now: 2.4
# Starting Game,  172
# CoolAI wins
# The AI scored  10.500000000000012 epsilon is 0.505649680340905
# The simpleAI difficulty is now: 2.7
# Starting Game,  173
# BoringAI wins
# The AI scored  -11.100000000000001 epsilon is 0.505144030660564
# The simpleAI difficulty is now: 2.4
# Starting Game,  174
# CoolAI wins
# The AI scored  11.300000000000013 epsilon is 0.5046388866299034
# The simpleAI difficulty is now: 2.7
# Starting Game,  175
# BoringAI wins
# The AI scored  -12.000000000000002 epsilon is 0.5041342477432735
# The simpleAI difficulty is now: 2.4
# Starting Game,  176
# CoolAI wins
# The AI scored  5.500000000000008 epsilon is 0.5036301134955302
# The simpleAI difficulty is now: 2.7
# Starting Game,  177
# CoolAI wins
# The AI scored  9.200000000000014 epsilon is 0.5031264833820347
# The simpleAI difficulty is now: 2.7
# Starting Game,  178
# CoolAI wins
# The AI scored  270.999999999999 epsilon is 0.5026233568986527
# The simpleAI difficulty is now: 2.7
# Starting Game,  179
# BoringAI wins
# The AI scored  -10.600000000000001 epsilon is 0.502120733541754
# The simpleAI difficulty is now: 2.4
# Starting Game,  180
# BoringAI wins
# The AI scored  -10.700000000000001 epsilon is 0.5016186128082123
# The simpleAI difficulty is now: 2.4
# Starting Game,  181
# CoolAI wins
# The AI scored  14.600000000000021 epsilon is 0.5011169941954041
# The simpleAI difficulty is now: 2.7
# Starting Game,  182
# BoringAI wins
# The AI scored  -12.199999999999996 epsilon is 0.5006158772012087
# The simpleAI difficulty is now: 2.4
# Starting Game,  183
# CoolAI wins
# The AI scored  5.500000000000005 epsilon is 0.5001152613240075
# The simpleAI difficulty is now: 2.7
# Starting Game,  184
# BoringAI wins
# The AI scored  -6.799999999999988 epsilon is 0.49961514606268353
# The simpleAI difficulty is now: 2.4
# Starting Game,  185
# BoringAI wins
# The AI scored  -7.3999999999999915 epsilon is 0.49911553091662086
# The simpleAI difficulty is now: 2.4
# Starting Game,  186
# BoringAI wins
# The AI scored  -9.700000000000001 epsilon is 0.4986164153857042
# The simpleAI difficulty is now: 2.4
# Starting Game,  187
# BoringAI wins
# The AI scored  -11.099999999999975 epsilon is 0.49811779897031855
# The simpleAI difficulty is now: 2.4
# Starting Game,  188
# BoringAI wins
# The AI scored  -9.6 epsilon is 0.49761968117134825
# The simpleAI difficulty is now: 2.4
# Starting Game,  189
# BoringAI wins
# The AI scored  -11.200000000000001 epsilon is 0.4971220614901769
# The simpleAI difficulty is now: 2.4
# Starting Game,  190
# BoringAI wins
# The AI scored  -9.5 epsilon is 0.49662493942868674
# The simpleAI difficulty is now: 2.4
# Starting Game,  191
# BoringAI wins
# The AI scored  -7.299999999999992 epsilon is 0.49612831448925804
# The simpleAI difficulty is now: 2.4
# Starting Game,  192
# BoringAI wins
# The AI scored  -10.3 epsilon is 0.4956321861747688
# The simpleAI difficulty is now: 2.4
# Starting Game,  193
# BoringAI wins
# The AI scored  -10.5 epsilon is 0.495136553988594
# The simpleAI difficulty is now: 2.4
# Starting Game,  194
# BoringAI wins
# The AI scored  -10.200000000000001 epsilon is 0.49464141743460543
# The simpleAI difficulty is now: 2.4
# Starting Game,  195
# BoringAI wins
# The AI scored  -11.900000000000002 epsilon is 0.49414677601717083
# The simpleAI difficulty is now: 2.4
# Starting Game,  196
# BoringAI wins
# The AI scored  -3.799999999999967 epsilon is 0.49365262924115366
# The simpleAI difficulty is now: 2.4
# Starting Game,  197
# CoolAI wins
# The AI scored  9.40000000000001 epsilon is 0.4931589766119125
# The simpleAI difficulty is now: 2.7
# Starting Game,  198
# BoringAI wins
# The AI scored  275.5999999999998 epsilon is 0.4926658176353006
# The simpleAI difficulty is now: 2.4
# Starting Game,  199
# BoringAI wins
# The AI scored  -10.0 epsilon is 0.4921731518176653
# The simpleAI difficulty is now: 2.4
# Starting Game,  200
# CoolAI wins
# The AI scored  11.40000000000001 epsilon is 0.49168097866584765
# The simpleAI difficulty is now: 2.7
# Starting Game,  201
# BoringAI wins
# The AI scored  -10.199999999999992 epsilon is 0.4911892976871818
# The simpleAI difficulty is now: 2.4
# Starting Game,  202
# BoringAI wins
# The AI scored  -22.999999999999957 epsilon is 0.4906981083894946
# The simpleAI difficulty is now: 2.4
# Starting Game,  203
# CoolAI wins
# The AI scored  -21.400000000000105 epsilon is 0.49020741028110515
# The simpleAI difficulty is now: 2.7
# Starting Game,  204
# BoringAI wins
# The AI scored  -11.200000000000001 epsilon is 0.48971720287082404
# The simpleAI difficulty is now: 2.4
# Starting Game,  205
# BoringAI wins
# The AI scored  -10.5 epsilon is 0.4892274856679532
# The simpleAI difficulty is now: 2.4
# Starting Game,  206
# CoolAI wins
# The AI scored  9.500000000000012 epsilon is 0.4887382581822853
# The simpleAI difficulty is now: 2.7
# Starting Game,  207
# BoringAI wins
# The AI scored  -10.8 epsilon is 0.488249519924103
# The simpleAI difficulty is now: 2.4
# Starting Game,  208
# CoolAI wins
# The AI scored  13.600000000000035 epsilon is 0.4877612704041789
# The simpleAI difficulty is now: 2.7
# Starting Game,  209
# BoringAI wins
# The AI scored  -14.99999999999998 epsilon is 0.4872735091337747
# The simpleAI difficulty is now: 2.4
# Starting Game,  210
# CoolAI wins
# The AI scored  11.300000000000008 epsilon is 0.4867862356246409
# The simpleAI difficulty is now: 2.7
# Starting Game,  211
# BoringAI wins
# The AI scored  -11.500000000000002 epsilon is 0.48629944938901626
# The simpleAI difficulty is now: 2.4
# Starting Game,  212
# BoringAI wins
# The AI scored  -8.59999999999999 epsilon is 0.48581314993962726
# The simpleAI difficulty is now: 2.4
# Starting Game,  213
# BoringAI wins
# The AI scored  -10.3 epsilon is 0.48532733678968765
# The simpleAI difficulty is now: 2.4
# Starting Game,  214
# BoringAI wins
# The AI scored  -13.399999999999988 epsilon is 0.48484200945289796
# The simpleAI difficulty is now: 2.4
# Starting Game,  215
# BoringAI wins
# The AI scored  -10.1 epsilon is 0.48435716744344504
# The simpleAI difficulty is now: 2.4
# Starting Game,  216
# BoringAI wins
# The AI scored  -11.3 epsilon is 0.4838728102760016
# The simpleAI difficulty is now: 2.4
# Starting Game,  217
# BoringAI wins
# The AI scored  -11.000000000000002 epsilon is 0.4833889374657256
# The simpleAI difficulty is now: 2.4
# Starting Game,  218
# BoringAI wins
# The AI scored  -10.8 epsilon is 0.48290554852825984
# The simpleAI difficulty is now: 2.4
# Starting Game,  219
# BoringAI wins
# The AI scored  -4.2999999999999865 epsilon is 0.4824226429797316
# The simpleAI difficulty is now: 2.4
# Starting Game,  220
# CoolAI wins
# The AI scored  302.9999999999959 epsilon is 0.4819402203367519
# The simpleAI difficulty is now: 2.7
# Starting Game,  221
# BoringAI wins
# The AI scored  9.699999999999989 epsilon is 0.4814582801164151
# The simpleAI difficulty is now: 2.4
# Starting Game,  222
# BoringAI wins
# The AI scored  -10.3 epsilon is 0.4809768218362987
# The simpleAI difficulty is now: 2.4
# Starting Game,  223
# BoringAI wins
# The AI scored  -10.700000000000001 epsilon is 0.4804958450144624
# The simpleAI difficulty is now: 2.4
# Starting Game,  224
# CoolAI wins
# The AI scored  11.600000000000009 epsilon is 0.48001534916944794
# The simpleAI difficulty is now: 2.7
# Starting Game,  225
# BoringAI wins
# The AI scored  -10.5 epsilon is 0.47953533382027846
# The simpleAI difficulty is now: 2.4
# Starting Game,  226
# BoringAI wins
# The AI scored  -10.0 epsilon is 0.4790557984864582
# The simpleAI difficulty is now: 2.4
# Starting Game,  227
# BoringAI wins
# The AI scored  -11.399999999999995 epsilon is 0.47857674268797173
# The simpleAI difficulty is now: 2.4
# Starting Game,  228
# BoringAI wins
# The AI scored  -11.600000000000001 epsilon is 0.47809816594528376
# The simpleAI difficulty is now: 2.4
# Starting Game,  229
# CoolAI wins
# The AI scored  10.00000000000001 epsilon is 0.47762006777933846
# The simpleAI difficulty is now: 2.7
# Starting Game,  230
# BoringAI wins
# The AI scored  -11.800000000000002 epsilon is 0.4771424477115591
# The simpleAI difficulty is now: 2.4
# Starting Game,  231
# BoringAI wins
# The AI scored  -10.200000000000001 epsilon is 0.47666530526384754
# The simpleAI difficulty is now: 2.4
# Starting Game,  232
# BoringAI wins
# The AI scored  -11.600000000000001 epsilon is 0.4761886399585837
# The simpleAI difficulty is now: 2.4
# Starting Game,  233
# CoolAI wins
# The AI scored  12.600000000000023 epsilon is 0.4757124513186251
# The simpleAI difficulty is now: 2.7
# Starting Game,  234
# BoringAI wins
# The AI scored  -10.0 epsilon is 0.4752367388673065
# The simpleAI difficulty is now: 2.4
# Starting Game,  235
# BoringAI wins
# The AI scored  -10.8 epsilon is 0.4747615021284392
# The simpleAI difficulty is now: 2.4
# Starting Game,  236
# BoringAI wins
# The AI scored  -10.5 epsilon is 0.47428674062631077
# The simpleAI difficulty is now: 2.4
# Starting Game,  237
# CoolAI wins
# The AI scored  -30.4 epsilon is 0.47381245388568444
# The simpleAI difficulty is now: 2.7
# Starting Game,  238
# CoolAI wins
# The AI scored  13.600000000000021 epsilon is 0.47333864143179877
# The simpleAI difficulty is now: 2.7
# Starting Game,  239
# BoringAI wins
# The AI scored  -13.399999999999997 epsilon is 0.472865302790367
# The simpleAI difficulty is now: 2.4
# Starting Game,  240
# BoringAI wins
# The AI scored  -9.9 epsilon is 0.4723924374875766
# The simpleAI difficulty is now: 2.4
# Starting Game,  241
# BoringAI wins
# The AI scored  -10.8 epsilon is 0.471920045050089
# The simpleAI difficulty is now: 2.4
# Starting Game,  242
# BoringAI wins
# The AI scored  -10.0 epsilon is 0.4714481250050389
# The simpleAI difficulty is now: 2.4
# Starting Game,  243
# BoringAI wins
# The AI scored  -10.0 epsilon is 0.47097667688003386
# The simpleAI difficulty is now: 2.4
# Starting Game,  244
# BoringAI wins
# The AI scored  -9.2 epsilon is 0.47050570020315385
# The simpleAI difficulty is now: 2.4
# Starting Game,  245
# BoringAI wins
# The AI scored  -6.099999999999991 epsilon is 0.4700351945029507
# The simpleAI difficulty is now: 2.4
# Starting Game,  246
# BoringAI wins
# The AI scored  -9.700000000000001 epsilon is 0.4695651593084478
# The simpleAI difficulty is now: 2.4
# Starting Game,  247
# BoringAI wins
# The AI scored  -9.9 epsilon is 0.4690955941491393
# The simpleAI difficulty is now: 2.4
# Starting Game,  248
# BoringAI wins
# The AI scored  102.60000000000036 epsilon is 0.46862649855499017
# The simpleAI difficulty is now: 2.4
# Starting Game,  249
# CoolAI wins
# The AI scored  9.200000000000014 epsilon is 0.46815787205643516
# The simpleAI difficulty is now: 2.7
# Starting Game,  250
# BoringAI wins
# The AI scored  -19.099999999999945 epsilon is 0.4676897141843787
# The simpleAI difficulty is now: 2.4
# Starting Game,  251
# BoringAI wins
# The AI scored  286.3999999999998 epsilon is 0.46722202447019434
# The simpleAI difficulty is now: 2.4
# Starting Game,  252
# BoringAI wins
# The AI scored  -10.700000000000001 epsilon is 0.46675480244572415
# The simpleAI difficulty is now: 2.4
# Starting Game,  253
# CoolAI wins
# The AI scored  8.700000000000012 epsilon is 0.4662880476432784
# The simpleAI difficulty is now: 2.7
# Starting Game,  254
# BoringAI wins
# The AI scored  -9.9 epsilon is 0.46582175959563515
# The simpleAI difficulty is now: 2.4
# Starting Game,  255
# CoolAI wins
# The AI scored  151.8000000000003 epsilon is 0.4653559378360395
# The simpleAI difficulty is now: 2.7
# Starting Game,  256
# BoringAI wins
# The AI scored  -10.700000000000001 epsilon is 0.4648905818982035
# The simpleAI difficulty is now: 2.4
# Starting Game,  257
# BoringAI wins
# The AI scored  -10.200000000000001 epsilon is 0.4644256913163053
# The simpleAI difficulty is now: 2.4
# Starting Game,  258
# BoringAI wins
# The AI scored  -9.9 epsilon is 0.46396126562498896
# The simpleAI difficulty is now: 2.4
# Starting Game,  259
# BoringAI wins
# The AI scored  -10.100000000000001 epsilon is 0.463497304359364
# The simpleAI difficulty is now: 2.4
# Starting Game,  260
# BoringAI wins
# The AI scored  -10.8 epsilon is 0.46303380705500463
# The simpleAI difficulty is now: 2.4
# Starting Game,  261
# CoolAI wins
# The AI scored  12.100000000000009 epsilon is 0.46257077324794965
# The simpleAI difficulty is now: 2.7
# Starting Game,  262
# BoringAI wins
# The AI scored  -7.099999999999996 epsilon is 0.4621082024747017
# The simpleAI difficulty is now: 2.4
# Starting Game,  263
# CoolAI wins
# The AI scored  12.000000000000009 epsilon is 0.46164609427222697
# The simpleAI difficulty is now: 2.7
# Starting Game,  264
# BoringAI wins
# The AI scored  -11.000000000000002 epsilon is 0.46118444817795473
# The simpleAI difficulty is now: 2.4
# Starting Game,  265
# BoringAI wins
# The AI scored  -10.5 epsilon is 0.4607232637297768
# The simpleAI difficulty is now: 2.4
# Starting Game,  266
# BoringAI wins
# The AI scored  349.6999999999982 epsilon is 0.46026254046604703
# The simpleAI difficulty is now: 2.4
# Starting Game,  267
# BoringAI wins
# The AI scored  -5.699999999999987 epsilon is 0.459802277925581
# The simpleAI difficulty is now: 2.4
# Starting Game,  268
# BoringAI wins
# The AI scored  -5.999999999999991 epsilon is 0.4593424756476554
# The simpleAI difficulty is now: 2.4
# Starting Game,  269
# BoringAI wins
# The AI scored  -15.299999999999985 epsilon is 0.45888313317200774
# The simpleAI difficulty is now: 2.4
# Starting Game,  270
# BoringAI wins
# The AI scored  -10.100000000000001 epsilon is 0.45842425003883575
# The simpleAI difficulty is now: 2.4
# Starting Game,  271
# BoringAI wins
# The AI scored  -3.199999999999971 epsilon is 0.4579658257887969
# The simpleAI difficulty is now: 2.4
# Starting Game,  272
# BoringAI wins
# The AI scored  -10.8 epsilon is 0.45750785996300813
# The simpleAI difficulty is now: 2.4
# Starting Game,  273
# BoringAI wins
# The AI scored  -11.800000000000002 epsilon is 0.4570503521030451
# The simpleAI difficulty is now: 2.4
# Starting Game,  274
# BoringAI wins
# The AI scored  -12.399999999999995 epsilon is 0.4565933017509421
# The simpleAI difficulty is now: 2.4
# Starting Game,  275
# BoringAI wins
# The AI scored  -10.5 epsilon is 0.45613670844919113
# The simpleAI difficulty is now: 2.4
# Starting Game,  276
# BoringAI wins
# The AI scored  -11.500000000000002 epsilon is 0.45568057174074195
# The simpleAI difficulty is now: 2.4
# Starting Game,  277
# CoolAI wins
# The AI scored  13.700000000000019 epsilon is 0.4552248911690012
# The simpleAI difficulty is now: 2.7
# Starting Game,  278
# CoolAI wins
# The AI scored  12.400000000000007 epsilon is 0.4547696662778322
# The simpleAI difficulty is now: 2.7
# Starting Game,  279
# BoringAI wins
# The AI scored  93.40000000000052 epsilon is 0.4543148966115544
# The simpleAI difficulty is now: 2.4
# Starting Game,  280
# BoringAI wins
# The AI scored  -10.3 epsilon is 0.4538605817149428
# The simpleAI difficulty is now: 2.4
# Starting Game,  281
# BoringAI wins
# The AI scored  -9.700000000000001 epsilon is 0.4534067211332279
# The simpleAI difficulty is now: 2.4
# Starting Game,  282
# BoringAI wins
# The AI scored  -11.500000000000002 epsilon is 0.45295331441209463
# The simpleAI difficulty is now: 2.4
# Starting Game,  283
# BoringAI wins
# The AI scored  -5.799999999999993 epsilon is 0.45250036109768255
# The simpleAI difficulty is now: 2.4
# Starting Game,  284
# BoringAI wins
# The AI scored  -9.9 epsilon is 0.45204786073658487
# The simpleAI difficulty is now: 2.4
# Starting Game,  285
# BoringAI wins
# The AI scored  -40.80000000000008 epsilon is 0.45159581287584827
# The simpleAI difficulty is now: 2.4
# Starting Game,  286
# BoringAI wins
# The AI scored  -14.999999999999979 epsilon is 0.4511442170629724
# The simpleAI difficulty is now: 2.4
# Starting Game,  287
# BoringAI wins
# The AI scored  248.39999999999998 epsilon is 0.4506930728459094
# The simpleAI difficulty is now: 2.4
# Starting Game,  288
# BoringAI wins
# The AI scored  -12.000000000000002 epsilon is 0.45024237977306353
# The simpleAI difficulty is now: 2.4
# Starting Game,  289
# BoringAI wins
# The AI scored  -11.099999999999987 epsilon is 0.44979213739329044
# The simpleAI difficulty is now: 2.4
# Starting Game,  290
# BoringAI wins
# The AI scored  -9.6 epsilon is 0.44934234525589717
# The simpleAI difficulty is now: 2.4
# Starting Game,  291
# BoringAI wins
# The AI scored  -9.5 epsilon is 0.44889300291064127
# The simpleAI difficulty is now: 2.4
# Starting Game,  292
# BoringAI wins
# The AI scored  -10.4 epsilon is 0.44844410990773065
# The simpleAI difficulty is now: 2.4
# Starting Game,  293
# BoringAI wins
# The AI scored  -10.100000000000001 epsilon is 0.4479956657978229
# The simpleAI difficulty is now: 2.4
# Starting Game,  294
# BoringAI wins
# The AI scored  -5.4999999999999885 epsilon is 0.44754767013202507
# The simpleAI difficulty is now: 2.4
# Starting Game,  295
# BoringAI wins
# The AI scored  -9.899999999999995 epsilon is 0.44710012246189307
# The simpleAI difficulty is now: 2.4
# Starting Game,  296
# CoolAI wins
# The AI scored  -25.20000000000001 epsilon is 0.44665302233943116
# The simpleAI difficulty is now: 2.7
# Starting Game,  297
# BoringAI wins
# The AI scored  -10.3 epsilon is 0.44620636931709173
# The simpleAI difficulty is now: 2.4
# Starting Game,  298
# BoringAI wins
# The AI scored  -12.799999999999999 epsilon is 0.44576016294777465
# The simpleAI difficulty is now: 2.4
# Starting Game,  299
# BoringAI wins
# The AI scored  -5.29999999999999 epsilon is 0.44531440278482687
# The simpleAI difficulty is now: 2.4
# Starting Game,  300
# BoringAI wins
# The AI scored  178.20000000000087 epsilon is 0.44486908838204203
# The simpleAI difficulty is now: 2.4
# Starting Game,  301
# BoringAI wins
# The AI scored  -10.600000000000001 epsilon is 0.44442421929366
# The simpleAI difficulty is now: 2.4
# Starting Game,  302
# BoringAI wins
# The AI scored  -5.7999999999999865 epsilon is 0.44397979507436636
# The simpleAI difficulty is now: 2.4
# Starting Game,  303
# CoolAI wins
# The AI scored  9.60000000000001 epsilon is 0.443535815279292
# The simpleAI difficulty is now: 2.7
# Starting Game,  304
# CoolAI wins
# The AI scored  10.600000000000009 epsilon is 0.4430922794640127
# The simpleAI difficulty is now: 2.7
# Starting Game,  305
# BoringAI wins
# The AI scored  -10.5 epsilon is 0.4426491871845487
# The simpleAI difficulty is now: 2.4
# Starting Game,  306
# CoolAI wins
# The AI scored  12.200000000000008 epsilon is 0.44220653799736415
# The simpleAI difficulty is now: 2.7
# Starting Game,  307
# CoolAI wins
# The AI scored  10.100000000000016 epsilon is 0.4417643314593668
# The simpleAI difficulty is now: 2.7
# Starting Game,  308
# BoringAI wins
# The AI scored  -6.199999999999992 epsilon is 0.4413225671279074
# The simpleAI difficulty is now: 2.4
# Starting Game,  309
# BoringAI wins
# The AI scored  -11.600000000000001 epsilon is 0.4408812445607795
# The simpleAI difficulty is now: 2.4
# Starting Game,  310
# BoringAI wins
# The AI scored  -9.8 epsilon is 0.4404403633162187
# The simpleAI difficulty is now: 2.4
# Starting Game,  311
# BoringAI wins
# The AI scored  -5.499999999999991 epsilon is 0.4399999229529025
# The simpleAI difficulty is now: 2.4
# Starting Game,  312
# BoringAI wins
# The AI scored  -10.100000000000001 epsilon is 0.4395599230299496
# The simpleAI difficulty is now: 2.4
# Starting Game,  313
# BoringAI wins
# The AI scored  -5.799999999999987 epsilon is 0.43912036310691965
# The simpleAI difficulty is now: 2.4
# Starting Game,  314
# BoringAI wins
# The AI scored  -12.999999999999986 epsilon is 0.43868124274381276
# The simpleAI difficulty is now: 2.4
# Starting Game,  315
# BoringAI wins
# The AI scored  -11.099999999999989 epsilon is 0.43824256150106894
# The simpleAI difficulty is now: 2.4
# Starting Game,  316
# CoolAI wins
# The AI scored  17.100000000000023 epsilon is 0.4378043189395679
# The simpleAI difficulty is now: 2.7
# Starting Game,  317
# BoringAI wins
# The AI scored  -7.999999999999995 epsilon is 0.4373665146206283
# The simpleAI difficulty is now: 2.4
# Starting Game,  318
# CoolAI wins
# The AI scored  12.100000000000009 epsilon is 0.4369291481060077
# The simpleAI difficulty is now: 2.7
# Starting Game,  319
# CoolAI wins
# The AI scored  843.799999999998 epsilon is 0.4364922189579017
# The simpleAI difficulty is now: 2.7
# Starting Game,  320
# CoolAI wins
# The AI scored  13.900000000000016 epsilon is 0.43605572673894377
# The simpleAI difficulty is now: 2.7
# Starting Game,  321
# BoringAI wins
# The AI scored  -9.6 epsilon is 0.43561967101220483
# The simpleAI difficulty is now: 2.4
# Starting Game,  322
# CoolAI wins
# The AI scored  10.500000000000007 epsilon is 0.43518405134119265
# The simpleAI difficulty is now: 2.7
# Starting Game,  323
# CoolAI wins
# The AI scored  989.199999999999 epsilon is 0.43474886728985146
# The simpleAI difficulty is now: 2.7
# Starting Game,  324
# BoringAI wins
# The AI scored  -10.600000000000001 epsilon is 0.4343141184225616
# The simpleAI difficulty is now: 2.4
# Starting Game,  325
# BoringAI wins
# The AI scored  -10.100000000000001 epsilon is 0.4338798043041391
# The simpleAI difficulty is now: 2.4
# Starting Game,  326
# BoringAI wins
# The AI scored  -10.3 epsilon is 0.43344592449983493
# The simpleAI difficulty is now: 2.4
# Starting Game,  327
# CoolAI wins
# The AI scored  11.400000000000006 epsilon is 0.4330124785753351
# The simpleAI difficulty is now: 2.7
# Starting Game,  328
# BoringAI wins
# The AI scored  -11.200000000000001 epsilon is 0.43257946609675973
# The simpleAI difficulty is now: 2.4
# Starting Game,  329
# BoringAI wins
# The AI scored  -10.600000000000001 epsilon is 0.432146886630663
# The simpleAI difficulty is now: 2.4
# Starting Game,  330
# BoringAI wins
# The AI scored  -9.4 epsilon is 0.4317147397440323
# The simpleAI difficulty is now: 2.4
# Starting Game,  331
# BoringAI wins
# The AI scored  -9.1 epsilon is 0.4312830250042883
# The simpleAI difficulty is now: 2.4
# Starting Game,  332
# BoringAI wins
# The AI scored  -9.9 epsilon is 0.430851741979284
# The simpleAI difficulty is now: 2.4
# Starting Game,  333
# BoringAI wins
# The AI scored  -9.4 epsilon is 0.43042089023730473
# The simpleAI difficulty is now: 2.4
# Starting Game,  334
# CoolAI wins
# The AI scored  12.20000000000001 epsilon is 0.4299904693470674
# The simpleAI difficulty is now: 2.7
# Starting Game,  335
# BoringAI wins
# The AI scored  -13.799999999999995 epsilon is 0.42956047887772036
# The simpleAI difficulty is now: 2.4
# Starting Game,  336
# BoringAI wins
# The AI scored  -10.0 epsilon is 0.42913091839884265
# The simpleAI difficulty is now: 2.4
# Starting Game,  337
# BoringAI wins
# The AI scored  -9.9 epsilon is 0.4287017874804438
# The simpleAI difficulty is now: 2.4
# Starting Game,  338
# BoringAI wins
# The AI scored  -10.600000000000001 epsilon is 0.42827308569296335
# The simpleAI difficulty is now: 2.4
# Starting Game,  339
# BoringAI wins
# The AI scored  -9.9 epsilon is 0.42784481260727036
# The simpleAI difficulty is now: 2.4
# Starting Game,  340
# BoringAI wins
# The AI scored  -12.3 epsilon is 0.4274169677946631
# The simpleAI difficulty is now: 2.4
# Starting Game,  341
# CoolAI wins
# The AI scored  266.3999999999985 epsilon is 0.42698955082686846
# The simpleAI difficulty is now: 2.7
# Starting Game,  342
# BoringAI wins
# The AI scored  -10.0 epsilon is 0.4265625612760416
# The simpleAI difficulty is now: 2.4
# Starting Game,  343
# BoringAI wins
# The AI scored  -10.100000000000001 epsilon is 0.42613599871476554
# The simpleAI difficulty is now: 2.4
# Starting Game,  344
# BoringAI wins
# The AI scored  -10.4 epsilon is 0.42570986271605077
# The simpleAI difficulty is now: 2.4
# Starting Game,  345
# BoringAI wins
# The AI scored  -10.3 epsilon is 0.4252841528533347
# The simpleAI difficulty is now: 2.4
# Starting Game,  346
# BoringAI wins
# The AI scored  -6.599999999999992 epsilon is 0.4248588687004814
# The simpleAI difficulty is now: 2.4
# Starting Game,  347
# BoringAI wins
# The AI scored  -12.899999999999991 epsilon is 0.4244340098317809
# The simpleAI difficulty is now: 2.4
# Starting Game,  348
# BoringAI wins
# The AI scored  -11.200000000000001 epsilon is 0.42400957582194915
# The simpleAI difficulty is now: 2.4
# Starting Game,  349
# BoringAI wins
# The AI scored  -6.599999999999991 epsilon is 0.4235855662461272
# The simpleAI difficulty is now: 2.4
# Starting Game,  350
# BoringAI wins
# The AI scored  -10.100000000000001 epsilon is 0.4231619806798811
# The simpleAI difficulty is now: 2.4
# Starting Game,  351
# BoringAI wins
# The AI scored  -10.700000000000001 epsilon is 0.4227388186992012
# The simpleAI difficulty is now: 2.4
# Starting Game,  352
# BoringAI wins
# The AI scored  -10.5 epsilon is 0.422316079880502
# The simpleAI difficulty is now: 2.4
# Starting Game,  353
# CoolAI wins
# The AI scored  375.49999999999744 epsilon is 0.4218937638006215
# The simpleAI difficulty is now: 2.7
# Starting Game,  354
# CoolAI wins
# The AI scored  8.500000000000021 epsilon is 0.42147187003682085
# The simpleAI difficulty is now: 2.7
# Starting Game,  355
# BoringAI wins
# The AI scored  -8.49999999999999 epsilon is 0.421050398166784
# The simpleAI difficulty is now: 2.4
# Starting Game,  356
# BoringAI wins
# The AI scored  -9.5 epsilon is 0.4206293477686172
# The simpleAI difficulty is now: 2.4
# Starting Game,  357
# BoringAI wins
# The AI scored  -23.399999999999952 epsilon is 0.4202087184208486
# The simpleAI difficulty is now: 2.4
# Starting Game,  358
# BoringAI wins
# The AI scored  -6.299999999999992 epsilon is 0.41978850970242776
# The simpleAI difficulty is now: 2.4
# Starting Game,  359
# BoringAI wins
# The AI scored  -10.200000000000001 epsilon is 0.41936872119272534
# The simpleAI difficulty is now: 2.4
# Starting Game,  360
# BoringAI wins
# The AI scored  -14.499999999999993 epsilon is 0.4189493524715326
# The simpleAI difficulty is now: 2.4
# Starting Game,  361
# BoringAI wins
# The AI scored  -10.3 epsilon is 0.41853040311906103
# The simpleAI difficulty is now: 2.4
# Starting Game,  362
# BoringAI wins
# The AI scored  -9.6 epsilon is 0.41811187271594197
# The simpleAI difficulty is now: 2.4
# Starting Game,  363
# BoringAI wins
# The AI scored  -10.8 epsilon is 0.417693760843226
# The simpleAI difficulty is now: 2.4
# Starting Game,  364
# BoringAI wins
# The AI scored  -11.200000000000001 epsilon is 0.4172760670823828
# The simpleAI difficulty is now: 2.4
# Starting Game,  365
# BoringAI wins
# The AI scored  -10.0 epsilon is 0.41685879101530043
# The simpleAI difficulty is now: 2.4
# Starting Game,  366
# BoringAI wins
# The AI scored  -5.799999999999987 epsilon is 0.41644193222428516
# The simpleAI difficulty is now: 2.4
# Starting Game,  367
# BoringAI wins
# The AI scored  -10.100000000000001 epsilon is 0.4160254902920609
# The simpleAI difficulty is now: 2.4
# Starting Game,  368
# BoringAI wins
# The AI scored  -6.299999999999994 epsilon is 0.4156094648017688
# The simpleAI difficulty is now: 2.4
# Starting Game,  369
# BoringAI wins
# The AI scored  -7.999999999999993 epsilon is 0.415193855336967
# ...
# The AI scored  -60.9000000000003 epsilon is 0.008131770887172497
# The simpleAI difficulty is now: 2.4
# Starting Game,  4301
# BoringAI wins
# The AI scored  2.400000000000027 epsilon is 0.008123639116285324
# The simpleAI difficulty is now: 2.4
# Starting Game,  4302
# BoringAI wins
# The AI scored  -4.900000000000112 epsilon is 0.008115515477169039
# The simpleAI difficulty is now: 2.4
# Starting Game,  4303
# BoringAI wins
# The AI scored  -4.8999999999999915 epsilon is 0.00810739996169187
# The simpleAI difficulty is now: 2.4
# Starting Game,  4304
# BoringAI wins
# The AI scored  1697.0000000000005 epsilon is 0.008099292561730177
# The simpleAI difficulty is now: 2.4
# Starting Game,  4305
# CoolAI wins
# The AI scored  8.400000000000018 epsilon is 0.008091193269168446
# The simpleAI difficulty is now: 2.7
# Starting Game,  4306
# BoringAI wins
# The AI scored  -8.9 epsilon is 0.008083102075899278
# The simpleAI difficulty is now: 2.4
# Starting Game,  4307
# CoolAI wins
# The AI scored  19.100000000000012 epsilon is 0.00807501897382338
# The simpleAI difficulty is now: 2.7
# Starting Game,  4308
# BoringAI wins
# The AI scored  -8.8 epsilon is 0.008066943954849555
# The simpleAI difficulty is now: 2.4
# Starting Game,  4309
# CoolAI wins
# The AI scored  23.300000000000004 epsilon is 0.008058877010894706
# The simpleAI difficulty is now: 2.7
# Starting Game,  4310
# CoolAI wins
# The AI scored  10.200000000000019 epsilon is 0.008050818133883812
# The simpleAI difficulty is now: 2.7
# Starting Game,  4311
# BoringAI wins
# The AI scored  638.1999999999999 epsilon is 0.008042767315749927
# The simpleAI difficulty is now: 2.4
# Starting Game,  4312
# BoringAI wins
# The AI scored  -8.2 epsilon is 0.008034724548434177
# The simpleAI difficulty is now: 2.4
# Starting Game,  4313
# BoringAI wins
# The AI scored  -8.8 epsilon is 0.008026689823885743
# The simpleAI difficulty is now: 2.4
# Starting Game,  4314
# CoolAI wins
# The AI scored  -29.100000000000023 epsilon is 0.008018663134061858
# The simpleAI difficulty is now: 2.7
# Starting Game,  4315
# CoolAI wins
# The AI scored  21.50000000000001 epsilon is 0.008010644470927796
# The simpleAI difficulty is now: 2.7
# Starting Game,  4316
# BoringAI wins
# The AI scored  7.200000000000006 epsilon is 0.008002633826456869
# The simpleAI difficulty is now: 2.4
# Starting Game,  4317
# CoolAI wins
# The AI scored  1.2000000000000117 epsilon is 0.007994631192630412
# The simpleAI difficulty is now: 2.7
# Starting Game,  4318
# BoringAI wins
# The AI scored  -9.8 epsilon is 0.007986636561437782
# The simpleAI difficulty is now: 2.4
# Starting Game,  4319
# CoolAI wins
# The AI scored  -23.300000000000004 epsilon is 0.007978649924876345
# The simpleAI difficulty is now: 2.7
# Starting Game,  4320
# CoolAI wins
# The AI scored  5.100000000000016 epsilon is 0.007970671274951468
# The simpleAI difficulty is now: 2.7
# Starting Game,  4321
# CoolAI wins
# The AI scored  13.700000000000006 epsilon is 0.007962700603676516
# The simpleAI difficulty is now: 2.7
# Starting Game,  4322
# BoringAI wins
# The AI scored  -3.999999999999984 epsilon is 0.00795473790307284
# The simpleAI difficulty is now: 2.4
# Starting Game,  4323
# CoolAI wins
# The AI scored  1739.9000000000128 epsilon is 0.007946783165169767
# The simpleAI difficulty is now: 2.7
# Starting Game,  4324
# BoringAI wins
# The AI scored  12.49999999999995 epsilon is 0.007938836382004598
# The simpleAI difficulty is now: 2.4
# Starting Game,  4325
# CoolAI wins
# The AI scored  14.100000000000003 epsilon is 0.007930897545622593
# The simpleAI difficulty is now: 2.7
# Starting Game,  4326
# BoringAI wins
# The AI scored  5.500000000000011 epsilon is 0.00792296664807697
# The simpleAI difficulty is now: 2.4
# Starting Game,  4327
# BoringAI wins
# The AI scored  5.900000000000011 epsilon is 0.007915043681428894
# The simpleAI difficulty is now: 2.4
# Starting Game,  4328
# BoringAI wins
# The AI scored  7.000000000000007 epsilon is 0.007907128637747465
# The simpleAI difficulty is now: 2.4
# Starting Game,  4329
# BoringAI wins
# The AI scored  -6.699999999999987 epsilon is 0.007899221509109718
# The simpleAI difficulty is now: 2.4
# Starting Game,  4330
# BoringAI wins
# The AI scored  7.500000000000007 epsilon is 0.007891322287600607
# The simpleAI difficulty is now: 2.4
# Starting Game,  4331
# BoringAI wins
# The AI scored  -22.999999999999943 epsilon is 0.007883430965313007
# The simpleAI difficulty is now: 2.4
# Starting Game,  4332
# CoolAI wins
# The AI scored  -28.00000000000002 epsilon is 0.007875547534347695
# The simpleAI difficulty is now: 2.7
# Starting Game,  4333
# BoringAI wins
# The AI scored  7.600000000000001 epsilon is 0.007867671986813348
# The simpleAI difficulty is now: 2.4
# Starting Game,  4334
# CoolAI wins
# The AI scored  0.9000000000000128 epsilon is 0.007859804314826534
# The simpleAI difficulty is now: 2.7
# Starting Game,  4335
# BoringAI wins
# The AI scored  -30.400000000000034 epsilon is 0.007851944510511707
# The simpleAI difficulty is now: 2.4
# Starting Game,  4336
# BoringAI wins
# The AI scored  -10.4 epsilon is 0.007844092566001196
# The simpleAI difficulty is now: 2.4
# Starting Game,  4337
# CoolAI wins
# The AI scored  19.999999999999993 epsilon is 0.007836248473435194
# The simpleAI difficulty is now: 2.7
# Starting Game,  4338
# BoringAI wins
# The AI scored  7.200000000000006 epsilon is 0.00782841222496176
# The simpleAI difficulty is now: 2.4
# Starting Game,  4339
# BoringAI wins
# The AI scored  6.300000000000011 epsilon is 0.007820583812736797
# The simpleAI difficulty is now: 2.4
# Starting Game,  4340
# BoringAI wins
# The AI scored  -8.9 epsilon is 0.00781276322892406
# The simpleAI difficulty is now: 2.4
# Starting Game,  4341
# BoringAI wins
# The AI scored  -10.2 epsilon is 0.007804950465695137
# The simpleAI difficulty is now: 2.4
# Starting Game,  4342
# BoringAI wins
# The AI scored  1528.400000000028 epsilon is 0.007797145515229442
# The simpleAI difficulty is now: 2.4
# Starting Game,  4343
# BoringAI wins
# The AI scored  -9.700000000000001 epsilon is 0.007789348369714212
# The simpleAI difficulty is now: 2.4
# Starting Game,  4344
# BoringAI wins
# The AI scored  -9.1 epsilon is 0.007781559021344498
# The simpleAI difficulty is now: 2.4
# Starting Game,  4345
# BoringAI wins
# The AI scored  -9.8 epsilon is 0.007773777462323154
# The simpleAI difficulty is now: 2.4
# Starting Game,  4346
# CoolAI wins
# The AI scored  13.800000000000004 epsilon is 0.007766003684860831
# The simpleAI difficulty is now: 2.7
# Starting Game,  4347
# BoringAI wins
# The AI scored  -21.199999999999953 epsilon is 0.00775823768117597
# The simpleAI difficulty is now: 2.4
# Starting Game,  4348
# BoringAI wins
# The AI scored  -8.9 epsilon is 0.007750479443494794
# The simpleAI difficulty is now: 2.4
# Starting Game,  4349
# BoringAI wins
# The AI scored  -10.599999999999989 epsilon is 0.0077427289640513
# The simpleAI difficulty is now: 2.4
# Starting Game,  4350
# BoringAI wins
# The AI scored  -49.000000000000014 epsilon is 0.007734986235087248
# The simpleAI difficulty is now: 2.4
# Starting Game,  4351
# CoolAI wins
# The AI scored  19.40000000000002 epsilon is 0.007727251248852161
# The simpleAI difficulty is now: 2.7
# Starting Game,  4352
# BoringAI wins
# The AI scored  -28.200000000000003 epsilon is 0.007719523997603309
# The simpleAI difficulty is now: 2.4
# Starting Game,  4353
# BoringAI wins
# The AI scored  637.1 epsilon is 0.007711804473605706
# The simpleAI difficulty is now: 2.4
# Starting Game,  4354
# CoolAI wins
# The AI scored  17.400000000000013 epsilon is 0.0077040926691321005
# The simpleAI difficulty is now: 2.7
# Starting Game,  4355
# CoolAI wins
# The AI scored  11.399999999999963 epsilon is 0.007696388576462969
# The simpleAI difficulty is now: 2.7
# Starting Game,  4356
# CoolAI wins
# The AI scored  13.700000000000006 epsilon is 0.007688692187886505
# The simpleAI difficulty is now: 2.7
# Starting Game,  4357
# CoolAI wins
# The AI scored  6.500000000000019 epsilon is 0.007681003495698619
# The simpleAI difficulty is now: 2.7
# Starting Game,  4358
# BoringAI wins
# The AI scored  -11.199999999999989 epsilon is 0.0076733224922029206
# The simpleAI difficulty is now: 2.4
# Starting Game,  4359
# BoringAI wins
# The AI scored  -9.999999999999988 epsilon is 0.007665649169710718
# The simpleAI difficulty is now: 2.4
# Starting Game,  4360
# BoringAI wins
# The AI scored  -8.4 epsilon is 0.007657983520541007
# The simpleAI difficulty is now: 2.4
# Starting Game,  4361
# BoringAI wins
# The AI scored  1527.8000000000281 epsilon is 0.007650325537020466
# The simpleAI difficulty is now: 2.4
# Starting Game,  4362
# BoringAI wins
# The AI scored  -8.099999999999962 epsilon is 0.007642675211483445
# The simpleAI difficulty is now: 2.4
# Starting Game,  4363
# BoringAI wins
# The AI scored  -8 epsilon is 0.007635032536271962
# The simpleAI difficulty is now: 2.4
# Starting Game,  4364
# BoringAI wins
# The AI scored  -8.9 epsilon is 0.00762739750373569
# The simpleAI difficulty is now: 2.4
# Starting Game,  4365
# BoringAI wins
# The AI scored  -9.1 epsilon is 0.007619770106231954
# The simpleAI difficulty is now: 2.4
# Starting Game,  4366
# BoringAI wins
# The AI scored  -48.20000000000002 epsilon is 0.0076121503361257226
# The simpleAI difficulty is now: 2.4
# Starting Game,  4367
# BoringAI wins
# The AI scored  -9.0 epsilon is 0.0076045381857895965
# The simpleAI difficulty is now: 2.4
# Starting Game,  4368
# CoolAI wins
# The AI scored  1.400000000000011 epsilon is 0.007596933647603807
# The simpleAI difficulty is now: 2.7
# Starting Game,  4369
# BoringAI wins
# The AI scored  -2.0999999999999925 epsilon is 0.007589336713956203
# The simpleAI difficulty is now: 2.4
# Starting Game,  4370
# BoringAI wins
# The AI scored  -9.899999999999956 epsilon is 0.007581747377242247
# The simpleAI difficulty is now: 2.4
# Starting Game,  4371
# BoringAI wins
# The AI scored  -9.0 epsilon is 0.007574165629865005
# The simpleAI difficulty is now: 2.4
# Starting Game,  4372
# CoolAI wins
# The AI scored  14.100000000000003 epsilon is 0.00756659146423514
# The simpleAI difficulty is now: 2.7
# Starting Game,  4373
# CoolAI wins
# The AI scored  15.000000000000002 epsilon is 0.007559024872770905
# The simpleAI difficulty is now: 2.7
# Starting Game,  4374
# BoringAI wins
# The AI scored  -8 epsilon is 0.007551465847898134
# The simpleAI difficulty is now: 2.4
# Starting Game,  4375
# CoolAI wins
# The AI scored  5.000000000000018 epsilon is 0.007543914382050236
# The simpleAI difficulty is now: 2.7
# Starting Game,  4376
# BoringAI wins
# The AI scored  -9.4 epsilon is 0.007536370467668185
# The simpleAI difficulty is now: 2.4
# Starting Game,  4377
# CoolAI wins
# The AI scored  9.200000000000017 epsilon is 0.007528834097200517
# The simpleAI difficulty is now: 2.7
# Starting Game,  4378
# BoringAI wins
# The AI scored  -10.599999999999989 epsilon is 0.007521305263103316
# The simpleAI difficulty is now: 2.4
# Starting Game,  4379
# CoolAI wins
# The AI scored  15.400000000000002 epsilon is 0.007513783957840213
# The simpleAI difficulty is now: 2.7
# Starting Game,  4380
# BoringAI wins
# The AI scored  -5.599999999999984 epsilon is 0.007506270173882373
# The simpleAI difficulty is now: 2.4
# Starting Game,  4381
# CoolAI wins
# The AI scored  24.1 epsilon is 0.00749876390370849
# The simpleAI difficulty is now: 2.7
# Starting Game,  4382
# CoolAI wins
# The AI scored  14.000000000000007 epsilon is 0.007491265139804782
# The simpleAI difficulty is now: 2.7
# Starting Game,  4383
# BoringAI wins
# The AI scored  -8 epsilon is 0.007483773874664977
# The simpleAI difficulty is now: 2.4
# Starting Game,  4384
# BoringAI wins
# The AI scored  -9.0 epsilon is 0.007476290100790312
# The simpleAI difficulty is now: 2.4
# Starting Game,  4385
# BoringAI wins
# The AI scored  -15.399999999999975 epsilon is 0.007468813810689522
# The simpleAI difficulty is now: 2.4
# Starting Game,  4386
# CoolAI wins
# The AI scored  21.10000000000001 epsilon is 0.007461344996878832
# The simpleAI difficulty is now: 2.7
# Starting Game,  4387
# BoringAI wins
# The AI scored  7.200000000000003 epsilon is 0.0074538836518819535
# The simpleAI difficulty is now: 2.4
# Starting Game,  4388
# CoolAI wins
# The AI scored  13.500000000000005 epsilon is 0.007446429768230072
# The simpleAI difficulty is now: 2.7
# Starting Game,  4389
# BoringAI wins
# The AI scored  -31.300000000000047 epsilon is 0.007438983338461842
# The simpleAI difficulty is now: 2.4
# Starting Game,  4390
# BoringAI wins
# The AI scored  -13.699999999999982 epsilon is 0.0074315443551233795
# The simpleAI difficulty is now: 2.4
# Starting Game,  4391
# BoringAI wins
# The AI scored  1011.1 epsilon is 0.007424112810768256
# The simpleAI difficulty is now: 2.4
# Starting Game,  4392
# BoringAI wins
# The AI scored  -12.99999999999999 epsilon is 0.007416688697957488
# The simpleAI difficulty is now: 2.4
# Starting Game,  4393
# CoolAI wins
# The AI scored  -22.400000000000013 epsilon is 0.00740927200925953
# The simpleAI difficulty is now: 2.7
# Starting Game,  4394
# BoringAI wins
# The AI scored  -23.399999999999945 epsilon is 0.007401862737250271
# The simpleAI difficulty is now: 2.4
# Starting Game,  4395
# BoringAI wins
# The AI scored  7.899999999999945 epsilon is 0.00739446087451302
# The simpleAI difficulty is now: 2.4
# Starting Game,  4396
# CoolAI wins
# The AI scored  29.899999999999924 epsilon is 0.007387066413638507
# The simpleAI difficulty is now: 2.7
# Starting Game,  4397
# BoringAI wins
# The AI scored  -8.8 epsilon is 0.007379679347224869
# The simpleAI difficulty is now: 2.4
# Starting Game,  4398
# CoolAI wins
# The AI scored  12.500000000000007 epsilon is 0.0073722996678776435
# The simpleAI difficulty is now: 2.7
# Starting Game,  4399
# CoolAI wins
# The AI scored  0.500000000000016 epsilon is 0.007364927368209766
# The simpleAI difficulty is now: 2.7
# Starting Game,  4400
# CoolAI wins
# The AI scored  22.19999999999999 epsilon is 0.007357562440841556
# The simpleAI difficulty is now: 2.7
# Starting Game,  4401
# CoolAI wins
# The AI scored  32.89999999999996 epsilon is 0.007350204878400714
# The simpleAI difficulty is now: 2.7
# Starting Game,  4402
# BoringAI wins
# The AI scored  -10.999999999999991 epsilon is 0.007342854673522314
# The simpleAI difficulty is now: 2.4
# Starting Game,  4403
# CoolAI wins
# The AI scored  13.600000000000009 epsilon is 0.007335511818848791
# The simpleAI difficulty is now: 2.7
# Starting Game,  4404
# CoolAI wins
# The AI scored  14.8 epsilon is 0.007328176307029943
# The simpleAI difficulty is now: 2.7
# Starting Game,  4405
# BoringAI wins
# The AI scored  -20.09999999999996 epsilon is 0.007320848130722913
# The simpleAI difficulty is now: 2.4
# Starting Game,  4406
# CoolAI wins
# The AI scored  380.89999999999907 epsilon is 0.00731352728259219
# The simpleAI difficulty is now: 2.7
# Starting Game,  4407
# BoringAI wins
# The AI scored  -0.7999999999999723 epsilon is 0.0073062137553095985
# The simpleAI difficulty is now: 2.4
# Starting Game,  4408
# BoringAI wins
# The AI scored  -10.3 epsilon is 0.007298907541554289
# The simpleAI difficulty is now: 2.4
# Starting Game,  4409
# BoringAI wins
# The AI scored  -30.400000000000034 epsilon is 0.0072916086340127344
# The simpleAI difficulty is now: 2.4
# Starting Game,  4410
# BoringAI wins
# The AI scored  -8.9 epsilon is 0.007284317025378722
# The simpleAI difficulty is now: 2.4
# Starting Game,  4411
# BoringAI wins
# The AI scored  -9.2 epsilon is 0.007277032708353343
# The simpleAI difficulty is now: 2.4
# Starting Game,  4412
# CoolAI wins
# The AI scored  15.3 epsilon is 0.00726975567564499
# The simpleAI difficulty is now: 2.7
# Starting Game,  4413
# CoolAI wins
# The AI scored  13.600000000000007 epsilon is 0.007262485919969345
# The simpleAI difficulty is now: 2.7
# Starting Game,  4414
# CoolAI wins
# The AI scored  22.800000000000004 epsilon is 0.007255223434049375
# The simpleAI difficulty is now: 2.7
# Starting Game,  4415
# CoolAI wins
# The AI scored  14.500000000000002 epsilon is 0.007247968210615326
# The simpleAI difficulty is now: 2.7
# Starting Game,  4416
# CoolAI wins
# The AI scored  335.5999999999999 epsilon is 0.007240720242404711
# The simpleAI difficulty is now: 2.7
# Starting Game,  4417
# BoringAI wins
# The AI scored  2.800000000000024 epsilon is 0.007233479522162306
# The simpleAI difficulty is now: 2.4
# Starting Game,  4418
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 234
#     222 state = new_state
#     224 ball.xy = ballPosX, ballPosY
# --> 234 pygame.display.flip()
#     236 #clock.tick(60)
#     238 ballVelX = ballVelX + acceleration * ballVelX
#
# KeyboardInterrupt:
